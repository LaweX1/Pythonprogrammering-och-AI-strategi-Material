# %% [markdown]
# Uppgifter för kapitel 3

# %% [markdown]
# 1: Det är en If statetment där man kontrollerar att " age " är större än " 18 ".
# Om det är sant: skriv ut " You can take a drivers liicense "
# Om det är falskt:  skriv ut " You are too young to take a drivers license "
#
# i detta fallet så är det sant

# %%
# 2
x = 7

if x > 10 :
    print("x is bigger than 10 ")
elif x < 10 and x > 5:
    print("x is not bigger than ten but is bigger than 5")
elif  x < 5: 
    print ("x is smaller than 5")
# Out:
# x is not bigger than ten but is bigger than 7

# %% [markdown]
# 3: Eftersom att 1 räknas som True. ( 0 räknas som False )

# %% [markdown]
# 4: Resultatet blir false eftersom 10 är inte större in 15.

# %% [markdown]
# 5: Resultatet blir True, för här kollar man om 7 är större eller lika med 7.

# %% [markdown]
# 6: Resultatet blir False.

# %% [markdown]
# 7: Det blir False.

# %% [markdown]
# 8: Det blir True.

# %% [markdown]
# 9: Det blir True.

# %% [markdown]
# 10: Skillnaden är att i det ena kodblocken kör man flera if statements, vilket kommer att resultera i att koden kommer att köra alla if checks.
#
# if / elif kodblocken, kontrollerar vilken kondition som stämmer och printar ut ett statement och stoppar där.
