# %% [markdown]
# This will be a file where i test different things. (My Playground)

# %%
# How to check objects id.

# A simple function that returns True or False
def id_comparison(id_1, id_2):
  print(f"{id_1 == id_2}")
    
my_object = 35
my_objects_id = id(my_object)
my_second_object = my_object

id_comparison( id_1 = my_object, id_2 = my_second_object )

# %%
# Check data type
my_string = "this is my test string"
type(my_string)

# %% [markdown]
# Calculations

# %%
# - Addition -

# this will return an int
addition_1 = 2 + 2 
 # this will return a float
addition_2 = 2 + 3.75
print(f" check result of addition_1: {addition_1}\n this is the result of addition_2: {addition_2}")

# %%
# - Divison -

 # This will show a result as an float value.
div_1 = 25 / 5
 # This will show a result as an int value. (if result is not an int, it will down size to closest int value)
div_2 = 25 // 5 
print(f"check value of div_1: {div_1}, and this is the value of div_2: {div_2}")

# %%
# - Modulo - operation / Remainder -
modulo_1 = 10 % 3 
print(modulo_1)

# %%
# - Multiplication & Strings -

multi_1 = 8 * 8 
multi_2 = int("4") * 4
multi_3 = "6" + str(6) # this will be a string value

print(f"value 1: {multi_1}\nvalue 2: {multi_2}\nvalue 3: {multi_3}")

# %% [markdown]
# Indexing / String / Tuple / List

# %%
indexing_excersise = "fun times"
print(f"get value from index 2: {indexing_excersise[2]}\nnow let's check what happens when slicing. value: {indexing_excersise[1:3]}")

# %%
# Counting characters using len & Split function.
string_value = "count this james"
#counting characters
using_len = len(string_value)
# Spliting and creating a list 
split_func = string_value.split(' ')
print(f"Print out both values: {using_len} \n {split_func} \n {split_func[1]}")

# %%
# - Tuple -

# Tuple is immutable 
my_tuple = (7,54,22,1,2,98,88)
get_second_last_value = my_tuple[-2]
tuple_slicing = my_tuple[2:7]
print(f"{get_second_last_value}\n{tuple_slicing}")

# %%
# - List -

def does_value_exist(value_1, value_2):
    # Good to know -> Using 'in' here but we can alltså use 'not in'.
    print(f"Result: {value_1 in value_2}")

# List is mutable
my_list = [2, 65, 78, 99, 22,34]
# Change value in index 0.
my_list[0] = 2345
# add value into list
my_list.append(899) 
# inserts a new value at a specific index and list length increases with 1.
my_list.insert(1,69)
# Convert to tuple
my_tuple_list = tuple(my_tuple)

# This will be False because wne we created the Tuple we created a new object
id_comparison( id_1 = my_tuple_list, id_2 = my_list)

# Search for value 
does_value_exist(value_1 = 88, value_2 = my_tuple_list)

# Using join
list_two = ["cars", "motorcycles", "boats"]
modified_list = " or ".join(list_two)

# %%
# - Dict -
my_dict = {"pears": 6, "bananas": 3, "apples": 10}

# Using get seems safer because if value does not exist we'll get 'None' value.
print(my_dict.get("pearszx"))
print(my_dict.get("pears"))

# Adding new Key / Value pair
my_dict["lemon"] = 9
# Updating value
my_dict["bananas"] = 7
# Checking all the keys
my_dict.keys()

# dict comprehension & items
# [(key, val) for key, val in my_dict.items()]
print("\n".join([f"{key.title()}: {val}" for key, val in my_dict.items()]))

# zip function
fruits = ["apples", "oranges", "bananas"]
amounts = (3, 6, 9)
new_fruit_dict = [(fruit, amount) for fruit, amount in zip(fruits, amounts)]
print(new_fruit_dict)

# %%
# Set
new_list = [1,22,1,44,5,6,3,2,11,8,9,1,2,3,4]
set_list = set(new_list)

# %%
# Union / Intersection / Difference / Frozenset / Range
A = {1,2,3,7,8,9}
B = {2,4,6,8,3}

union_variable = A.union(B) # gather all 
intersection_variable = A.intersection(B) # What 'A' & 'B' have in common.
difference_variable = A.difference(B) # Diffrence between 'A' & 'B'
symmetric_difference = A.symmetric_difference(B) # All the differences.
print(f"{union_variable}\n{intersection_variable}\n{difference_variable}\n{symmetric_difference}")

# Frozenset (immutable version of set)
C = frozenset(B) 

# Range
D = range(5)
E = "This is a loop test"

for i in D:
    print(E)

# %%
fruits = ['apple', 'banana', 'pear','melon','lemon']

for (i,fruit) in enumerate(fruits):
    print(i, fruit)
# Out:
# 0 apple
# 1 banana
# 2 pear
# 3 melon
# 4 lemon
