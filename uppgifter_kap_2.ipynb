# %%
# Uppgifter ifrån kapitel 2

# 1
num_1 = 5
num_2 = 3
my_result = num_1 + num_2
print(my_result)

# 2 
number_1 = 10
number_2 = 7
my_mult_result = number_1 * number_2
print(my_mult_result)

#3
10 % 3 
"""
Koden ovanför visar resterande värde.
så i detta fallet blir svaret 1. 
Anledningen -> 3 * 3 = 9 och då har vi 1 kvar. 
"""

#4
"""
27//6 kommer att dividera och ge ett hel tal. 
Den kommer att avrunda ned till närmste hel tal.
"""

#5
"""
det som är fel i koden är att man använder singel quation både i texten samt 
när man def. stringen. rätt sätt, se nedan.
"""
print("it's fun to learn Python!")

#6
"Det skriver ut koden 3ggr."

#7
full_name = "Anna Andersson"
print(full_name[0:5])

#8
len(full_name)
"svar: 14"

#9
founder = "Guido van Rossum"
language = "Python is really fun to learn!"
print(f"Hello {founder}, {language}.")

#10
"Koden blir fel för att tuple är immutable"

#11
"""
Koden skapar en tuple med en lista.
first print: skriver ut info ifrån index 0
andra print: skriver ut sista index
sista print: priver ut index 1 & 2
"""

#12
my_tuple = ('languages', ['Python', 'Java', 'C', 'R'],'apples')
type(my_tuple)

#13
"Koden är ändrar värdet i index 1 till nytt värede '7' "

#14
my_first_list = [10, 5, 'hi', 3]
type(my_first_list)

#15
shopping_list = ['apple', 'banana', 'grapes', 'eggs','milk']
len(shopping_list)

#16
shopping_list.append('bread')
print(shopping_list)

#17
my_numbers = [1, 7, 2, 7, 10, 7]
print(my_numbers.count(7))

#18
one_tuple = (10, 5, 3)
one_list = list(one_tuple)

#19
"Skriver ut värdet för 'Goran' "

#20
my_first_dict = {'Anna': 38, 'Goran': 19, 'Lennart':59, 'Halimah': 28}
type(my_first_dict)

#21
"Set tar hand om och eliminerar alla dupplikationer"

#22
A = {1,2,3,4,5}
B = {3,10,5,7}

A.difference(B)
A.intersection(B)
A.union(B)

#23
list_a = [1, 2, 3, 4, 5]
list_b = [5, 6, 10, 21]
